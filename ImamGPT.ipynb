# %%
import os
REPO = "https://github.com/bamlhs/imamgpt.git"
DIR  = "/content/imamgpt"

if os.path.exists(DIR):
    # !cd {DIR} && git pull
else:
    # !git clone {REPO} {DIR}
# %cd {DIR}

# deps (torch is already in Colab)
# !pip install -q -r requirements.txt

# ngrok needs your authtoken on a fresh VM
# Get yours at https://dashboard.ngrok.com/get-started/your-authtoken
# !ngrok config add-authtoken YOUR_NGROK_TOKEN

# %%
# !cd /content/imamgpt && git pull && python main.py
